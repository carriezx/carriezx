# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %% [markdown]
# # Data Preprocessing
#
# 1. Check the missing data, some "NA" means None, like basement and garage, pool related...
# 2. Electrical in train data, drop the missing rows, just a few
# 3. LotFrontage is related to Neighborhood, fillna with Neighborhood median

# %%
replace_na_cols = train_data.columns[train_data.columns.str.startswith(('Bsmt', 'Garage', 'MasVnr'))].to_list() + ['FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature', 'Alley']
train_data[replace_na_cols] = train_data[replace_na_cols].fillna('None')
test_data[replace_na_cols] = test_data[replace_na_cols].fillna('None')
train_data['LotFrontage'] = train_data.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))
test_data['LotFrontage'] = test_data.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))

train_data = train_data.dropna(subset=['Electrical'])

# %%
(test_data.isnull().sum()).sort_values(ascending=False).head(20)
# Out:
# LotFrontage     227
# MSZoning          4
# Utilities         2
# Functional        2
# Exterior1st       1
# KitchenQual       1
# SaleType          1
# TotalBsmtSF       1
# Exterior2nd       1
# GarageFinish      0
# GarageYrBlt       0
# GarageType        0
# FireplaceQu       0
# Fireplaces        0
# TotRmsAbvGrd      0
# Id                0
# KitchenAbvGr      0
# BedroomAbvGr      0
# FullBath          0
# BsmtHalfBath      0
# dtype: int64

# %%
train_data['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64
